# %%
import torch

# %%
x = torch.rand(5, requires_grad=True)
x
# Out:
# tensor([0.8755, 0.6907, 0.5553, 0.2138, 0.2917], requires_grad=True)

# %%
# calculate some gradient

# %%
y= x + 2
y # grad_fn=<AddBackward0
# Out:
# tensor([2.8755, 2.6907, 2.5553, 2.2138, 2.2917], grad_fn=<AddBackward0>)

# %%
z = y*y*2
z # grad_fn=<MulBackward
# Out:
# tensor([16.5370, 14.4797, 13.0588,  9.8016, 10.5035], grad_fn=<MulBackward0>)

# %%
z = z.mean()
z # grad_fn=<MeanBackward
# Out:
# tensor(12.8761, grad_fn=<MeanBackward0>)

# %%
# calculate grad

# %%
z.backward()
print(x.grad)
# Out:
# tensor([2.3004, 2.1526, 2.0442, 1.7710, 1.8333])

# %% [markdown]
# # Preventing Gardient history

# %%
## In pytorch trailing _ meaning this function is modified varibale inplace

# %%
x = torch.randn(3, requires_grad=True)
print(x)

# x.requires_grad_(False)
# x.detach()     # creating new tensor donesnt requires the gradient
# with torch.no_grad():

with torch.no_grad():
  y = x+2
  print(y) # o/p = doesnt show gradient fun attribute
# Out:
# tensor([-1.2216, -0.4624, -0.0386], requires_grad=True)
# tensor([0.7784, 1.5376, 1.9614])

# %% [markdown]
# # Training Example

# %%
weights = torch.ones(4, requires_grad=True)

for epoch in range(2):
  model_output = (weights*3).sum()
  model_output.backward()
  print(weights.grad)
# Out:
# tensor([3., 3., 3., 3.])
# tensor([6., 6., 6., 6.])

# %%
weights = torch.ones(4, requires_grad=True)

for epoch in range(2):
  model_output = (weights*3).sum()
  model_output.backward()
  print(weights.grad)
  weights.grad.zero_()
# Out:
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])

# %%
# optimozers used

# %%
# optimizer
weights = torch.ones(4, requires_grad=True)

optimizer = torch.optim.SGD(weights, lr=0.01)
optimizer.step()
optimizer.zero_grad()

# %%
# !pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript('UQBlRjNW74g', languages='mr')
# Out:
# ---------------------------------------------------------------------------
# TranscriptsDisabled                       Traceback (most recent call last)
# <ipython-input-14-179286331002> in <cell line: 3>()
#       1 from youtube_transcript_api import YouTubeTranscriptApi
#       2
# ----> 3 YouTubeTranscriptApi.get_transcript('UQBlRjNW74g', languages='mr')
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_api.py in get_transcript(cls, video_id, languages, proxies, cookies, preserve_formatting)
#     135         """
#     136         assert isinstance(video_id, str), "`video_id` must be a string"
# --> 137         return cls.list_transcripts(video_id, proxies, cookies).find_transcript(languages).fetch(preserve_formatting=preserve_formatting)
#     138
#     139     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_api.py in list_transcripts(cls, video_id, proxies, cookies)
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Replace 'URL' with the URL of the webpage you want to scrape
url = 'https://vivekpatait.blogspot.com/'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find and extract Marathi text (example for paragraph tags <p>)
marathi_text = []
for paragraph in soup.find_all('p'):
    if paragraph.get_text():  # Check if the paragraph has text content
        marathi_text.append(paragraph.get_text())

# Print the extracted Marathi text
for text in marathi_text:
    print(text)
# Out:
# Marathi stories, kavita
# स्वामी त्रिकालदर्शी आपल्या गुहेत ध्यानस्थ बसले होते. २५ वर्षाचे युवा व्यापारी धर्मदेव स्वामींच्या दर्शनार्थ आले. आपली समस्या स्वामींच्या पुढे मांडत धर्मदेव म्हणाले, माझ्या वडिलांचा मृत्यू असमय झाला. त्यांची इच्छा व्यापारातून मिळालेल्या फायद्याचा अधिकांश भाग समाजसेवेसाठी खर्च करायची होती. पण गेल्या काही वर्षांपासून व्यापारात सतत तोटा होत असल्याने, ईच्छा असूनही ते समाजसेवा करू शकले नाही. वडिलांच्या मृत्यू  समयी  त्यांच्या समस्त इच्छा पूर्ण करण्याचे मी वचन दिले आहे. त्यांच्या एवढ्या इच्छा कश्या पूर्ण करू हेच मला कळत नाही. स्वामीजी धर्मदेव कडे पहात  हसत-हसत म्हणाले, त्यांच्या सर्व इच्छा तू सहज पूर्ण करू शकतो. स्वामीजींनी धर्मदेवला एक कान मंत्र दिला.
# ...
