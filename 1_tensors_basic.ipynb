# %%
import torch

# %%
x= torch.empty(1,2) #2d
x
# Out:
# tensor([[2.2179e+12, 4.4773e-41]])

# %%
x= torch.empty(2,2,3)  #3d
x
# Out:
# tensor([[[-1.5458e-27,  3.1270e-41, -4.9511e-27],
#          [ 3.1270e-41,  2.1286e+12,  1.9618e-44]],
#
#         [[ 5.5219e+03, -6.7513e-07,  2.1286e+12],
#          [ 4.4773e-41, -5.2717e+12,  3.8582e+16]]])

# %%
x= torch.rand(3,2)
x
# Out:
# tensor([[0.4137, 0.6332],
#         [0.8558, 0.8317],
#         [0.4024, 0.6879]])

# %%
x= torch.zeros(2,3)
x
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
x.dtype
# Out:
# torch.float32

# %%
x= torch.zeros(2,3, dtype=torch.int)
x
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]], dtype=torch.int32)

# %%
x= torch.zeros(2,3, dtype=torch.float16)
x
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]], dtype=torch.float16)

# %%
x.size()
# Out:
# torch.Size([2, 3])

# %%
x = torch.rand(2,3)
y = torch.rand(2,3)
print(x)
print(y)
# Out:
# tensor([[0.9921, 0.6728, 0.8823],
#         [0.9363, 0.3306, 0.5893]])
# tensor([[0.5764, 0.0849, 0.8348],
#         [0.9983, 0.9402, 0.5342]])

# %%
z = x.add_(y)
z
# Out:
# tensor([[1.5686, 0.7577, 1.7171],
#         [1.9347, 1.2707, 1.1235]])

# %%
print(x)
print(y)
# Out:
# tensor([[1.5686, 0.7577, 1.7171],
#         [1.9347, 1.2707, 1.1235]])
# tensor([[2.1450, 0.8426, 2.5519],
#         [2.9330, 2.2109, 1.6578]])

# %%
y.add_(x)
# Out:
# tensor([[2.1450, 0.8426, 2.5519],
#         [2.9330, 2.2109, 1.6578]])

# %%
z = x-y
z = torch.sub(x,y)
z
# Out:
# tensor([[-0.5764, -0.0849, -0.8348],
#         [-0.9983, -0.9402, -0.5342]])

# %%
print(x)
print(y)
# Out:
# tensor([[1.5686, 0.7577, 1.7171],
#         [1.9347, 1.2707, 1.1235]])
# tensor([[2.1450, 0.8426, 2.5519],
#         [2.9330, 2.2109, 1.6578]])

# %%
z = x*y
z = torch.mul(x,y)
z
# Out:
# tensor([[3.3645, 0.6385, 4.3819],
#         [5.6743, 2.8095, 1.8625]])

# %%
x = torch.rand(5,4)
x
# Out:
# tensor([[0.4921, 0.2743, 0.5312, 0.2637],
#         [0.0638, 0.2144, 0.6055, 0.5223],
#         [0.6879, 0.9372, 0.6655, 0.1715],
#         [0.8151, 0.0305, 0.2343, 0.6648],
#         [0.0729, 0.1244, 0.5113, 0.4366]])

# %%
x[:, 1]
# Out:
# tensor([0.2743, 0.2144, 0.9372, 0.0305, 0.1244])

# %%
x[:, 1:2]
# Out:
# tensor([[0.2743],
#         [0.2144],
#         [0.9372],
#         [0.0305],
#         [0.1244]])

# %%
x[:, 1:3]
# Out:
# tensor([[0.2743, 0.5312],
#         [0.2144, 0.6055],
#         [0.9372, 0.6655],
#         [0.0305, 0.2343],
#         [0.1244, 0.5113]])

# %%
x[4, :]
# Out:
# tensor([0.0729, 0.1244, 0.5113, 0.4366])

# %%
#

# %%
import numpy as np

# %%
a= torch.ones(3,2)
a
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
b =a.numpy()
b
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]], dtype=float32)

# %%
# tensor on cpu not gpu both objacts same location

# %%
a.add_(1)
print(a)
print(b)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# [[2. 2.]
#  [2. 2.]
#  [2. 2.]]

# %%
a = np.ones(5)
print(a)
b = torch.from_numpy(a)
b
# Out:
# [1. 1. 1. 1. 1.]
# tensor([1., 1., 1., 1., 1.], dtype=torch.float64)

# %%
a += 2
print(a)
print(b)
# Out:
# [3. 3. 3. 3. 3.]
# tensor([3., 3., 3., 3., 3.], dtype=torch.float64)

# %%
# GPU

# %%
if torch.cuda.is_available():
  device = torch.device("cuda")
  x = torch.ones(5, device=device)
  y = torch.ones(6)
  y = y.to(device)
  z = x + y
  z = z.to('cpu')

# %%
import torch
print("cuda") if torch.cuda.is_available() else print('_cpu')
# Out:
# cuda

# %%
x = torch.ones(5, requires_grad=True)
x
# Out:
# tensor([1., 1., 1., 1., 1.], requires_grad=True)
